# %% [markdown]
# ## Instal Dependencies

# %%
# !pip install azure-cognitiveservices-vision-computervision
# !pip install azure.cognitiveservices.vision.customvision

# %%
import os
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient

# %% [markdown]
# ## Setup Custom Model Keys

# %%
base_image_url = os.getcwd() + '\\images\\'
training_key = "8b70ead3443f478bb5a4254d94bd8d2e"
ENDPOINT = "https://ms-customvision.cognitiveservices.azure.com/"
publish_iteration_name = "hijab-scarf-iteration3"

# %% [markdown]
# ## Create a Classification Function

# %%
def image_classifier(filename):
    predictor = CustomVisionPredictionClient(prediction_key, endpoint=ENDPOINT)

    with open(base_image_url + filename, "rb") as image_contents:
        results = predictor.classify_image(
            project.id, publish_iteration_name, image_contents.read())

        # Display the results.
        for prediction in results.predictions:
            print("\t" + prediction.tag_name +
                  ": {0:.2f}%".format(prediction.probability * 100))

# %% [markdown]
# ## Get Custom Vision Project

# %%
def find_project(project_name):
    trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)
    for proj in trainer.get_projects():
        if (proj.name == project_name):
            return proj 
        
    return null

project = find_project('Aljazeera')
project

# %% [markdown]
# ## Classify Images

# %%
from IPython.display import Image
Image(filename=base_image_url + "file-photo-hijab.jpg")

# %%
image_classifier("file-photo-hijab.jpg")
# Out:
# 	Hijab: 100.00%
# 	HeadScarf: 0.00%

# %%
from IPython.display import Image
Image(filename=base_image_url + "head_scarf.jpg")

# %%
image_classifier("head_scarf.jpg")
# Out:
# 	HeadScarf: 100.00%
# 	Hijab: 0.00%
